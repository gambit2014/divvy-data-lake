# %%
# %sql
SELECT *
FROM databricks_300941.default.dim_station
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dim_station.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("databricks_300941.default.dim_station")

# %%
display(dim_station)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import col

dim_station = bronze_stations.select(
    col("station_id"),
    col("name"),
    col("latitude"),
    col("longitude")
)

# %%
bronze_stations = spark.table("databricks_300941.default.bronze_stations")
